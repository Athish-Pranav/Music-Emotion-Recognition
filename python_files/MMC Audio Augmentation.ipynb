# %% [markdown]
# ## 1. Import library

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import cv2
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
import librosa
from scipy.io import wavfile

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D,BatchNormalization, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
dir25 = "D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio"
data25 = os.listdir(dir25)
file_dir25 = []
count = 0

for mooddir25 in data25:
    if(not r'.' in mooddir25):
        moodDirName25 = os.path.join(dir25,mooddir25)
        mooddir25=np.array(os.listdir(moodDirName25))
        for audio in mooddir25:
            if(audio[-3:]=='mp3'):
                count+=1
                fn=os.path.join(moodDirName25,audio)
                file_dir25.append(fn)
                print(str(count),fn)
# Out:
# 1 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\adana_kopru_basi_murat_kursun.mp3
# 2 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\ah_nerede_vah_nerede_fusun_onal.mp3
# 3 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\altun_kardesler_erik_dali.mp3
# 4 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\antebin_hamamlar_cesitli_sanatci.mp3
# 5 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\antebin_kalesine_ibrahim_tatlises.mp3
# 6 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\arap_kizi_ibrahim_tatlises.mp3
# 7 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\arpa_bugday_daneler_muazzez_ersoy.mp3
# 8 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\arzu_kus_adana_kopru_basi.mp3
# 9 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\askimiz_bitecek_cansu_koc.mp3
# 10 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\ayas_yollar_sumer_ezgu.mp3
# 11 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\aya_benzer_mustafa_sandal.mp3
# 12 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\aynali_koruk_zara.mp3
# 13 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\ayse_ozyilmazel_pardon.mp3
# 14 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\ayva_cicek_acmis_fasli_beyoglu.mp3
# 15 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\bagya_girdimbag_budanmis_rustem.mp3
# 16 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\bag_gel_bostana_gel_kubat.mp3
# 17 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\bahcelerde_borulce_eyll.mp3
# 18 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\baran_bayraktar_gol.mp3
# 19 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\bekar_gezelim_gurup_lacin.mp3
# 20 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\beyaz_gul_kirmizi_gul_ibrahim_tatlises.mp3
# 21 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\beyoglunda_gezersin.mp3
# 22 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\bu_gece_uyumamisan.mp3
# 23 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\cakmak_cakmaga_geldik_cesitli_sanatci.mp3
# 24 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\cal_para_suzan_kardes.mp3
# 25 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\cay_elinden_oteye_sevval_sam.mp3
# 26 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\cekirge_oguz_yilmaz.mp3
# 27 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\cit_cit_cetene_ahmet_kurt.mp3
# 28 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\comce_gelin_olasan_urfa.mp3
# 29 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\daglar_kizi_reyhan_yusel_ozkasap.mp3
# 30 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\dane_dane_benleri_var_burcin.mp3
# 31 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\darildinmi_cicim_bana_fasli_beyoglu.mp3
# 32 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\davullu_zurnali_oyun_havasi.mp3
# 33 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\delalim_urfa_sira_geceleri.mp3
# 34 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\diyarbakir_lorke_halayi.mp3
# 35 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\diyar_bakir_guzel_baglar_yahya_cekirge.mp3
# 36 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\dugmeli_izzet_altinmese.mp3
# 37 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\erkilet_guzeli_meski_fasil.mp3
# 38 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\ertan-ersan-oy-gelin-oy-damat-part.mp3
# 39 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\esarbini_yan_baglama_ibrahim_tatlises.mp3
# 40 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\evlere_senlik_sinan_ozen.mp3
# 41 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\fistan_bictim_dar_geldi_huriye_mustafa_keser.mp3
# 42 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\gimildan_efe.mp3
# 43 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\gir_kanima_harun_kolcak.mp3
# 44 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\gokte_yildiz_aymisun.mp3
# 45 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\gozleri_aska_gulen_funda_arar.mp3
# 46 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\gulum_benim_muazzez_ersoy.mp3
# 47 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\gul_doktum_yollarina_tarkan.mp3
# 48 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\hadi_gari_sende_gel.mp3
# 49 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\hele_yar_zalim_yar_zekeriya_unlu.mp3
# 50 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\heycan_serdar_ortac.mp3
# 51 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\ilvanlim_belkis_akkale.mp3
# 52 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\indim_havuz_basina_fasli_beyoglu.mp3
# 53 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kadifeden_kesesi_fasli_beyoglu.mp3
# 54 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kalenin_bedenleri_zara.mp3
# 55 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\karabiberim_serdar_ortac.mp3
# 56 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kara_kopru_narliktir_cesitli_sanatci.mp3
# 57 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kaslarin_karasina_gulsen_kutlu.mp3
# 58 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kesik_cayir_bedia_akarturk.mp3
# 59 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kim_arar_nilufer.mp3
# 60 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kiraz_dali_mehtap_koc.mp3
# 61 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kocari_kazim_koyuncu.mp3
# 62 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\kondurama_kum_doldu_cesitli_sanatci.mp3
# 63 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\maden_dagi_izzet_altinmese.mp3
# 64 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\makarak_sari_baglar_kirac.mp3
# 65 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\mardin_kapisindan_atyalyamadm_kazanc_bedih.mp3
# 66 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\mektebin_bacalari_yahya_cekirge.mp3
# 67 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\merdivanim_kirik_oyun_havasi.mp3
# 68 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\minnos_ceylan.mp3
# 69 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000040632.mp3
# 70 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000082187.mp3
# 71 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000249842.mp3
# 72 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000364027.mp3
# 73 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000392975.mp3
# 74 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000414517.mp3
# 75 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000442827.mp3
# 76 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000540286.mp3
# 77 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000664362.mp3
# 78 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0000992846.mp3
# 79 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001053268.mp3
# 80 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001189913.mp3
# 81 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001217651.mp3
# 82 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001236649.mp3
# 83 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001335920.mp3
# 84 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001340713.mp3
# 85 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001418045.mp3
# 86 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001521543.mp3
# 87 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001586807.mp3
# 88 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001605268.mp3
# 89 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001671399.mp3
# 90 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001680969.mp3
# 91 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001703346.mp3
# 92 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001753457.mp3
# 93 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001757676.mp3
# 94 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0001898830.mp3
# 95 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002033629.mp3
# 96 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002053300.mp3
# 97 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002119439.mp3
# 98 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002161109.mp3
# 99 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002222957.mp3
# 100 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002262181.mp3
# 101 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002297016.mp3
# 102 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002351905.mp3
# 103 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002366291.mp3
# 104 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002391847.mp3
# 105 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002525905.mp3
# 106 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002532237.mp3
# 107 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002538335.mp3
# 108 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002595792.mp3
# 109 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002698706.mp3
# 110 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002794078.mp3
# 111 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0002894033.mp3
# 112 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003044417.mp3
# 113 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003144898.mp3
# 114 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003170370.mp3
# 115 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003213835.mp3
# 116 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003243311.mp3
# 117 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003248394.mp3
# 118 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003272751.mp3
# 119 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003286463.mp3
# 120 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003390733.mp3
# 121 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003570082.mp3
# 122 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003594672.mp3
# 123 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003603772.mp3
# 124 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003669917.mp3
# 125 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003724610.mp3
# 126 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003788939.mp3
# 127 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003794106.mp3
# 128 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003903675.mp3
# 129 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0003949060.mp3
# 130 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004032071.mp3
# 131 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004037272.mp3
# 132 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004122617.mp3
# 133 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004141823.mp3
# 134 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004339430.mp3
# 135 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004428604.mp3
# 136 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004447226.mp3
# 137 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004669603.mp3
# 138 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004683099.mp3
# 139 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004711079.mp3
# 140 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004751933.mp3
# 141 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0004896738.mp3
# 142 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005003824.mp3
# 143 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005083488.mp3
# 144 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005163122.mp3
# 145 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005239610.mp3
# 146 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005265641.mp3
# 147 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005331755.mp3
# 148 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005469880.mp3
# 149 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005478759.mp3
# 150 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005523766.mp3
# 151 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005625762.mp3
# 152 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005674518.mp3
# 153 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005713768.mp3
# 154 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005737276.mp3
# 155 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005752234.mp3
# 156 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0005832516.mp3
# 157 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0006096934.mp3
# 158 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0006315323.mp3
# 159 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0006367176.mp3
# 160 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0006540794.mp3
# 161 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0006640857.mp3
# 162 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0006747288.mp3
# 163 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0006996768.mp3
# 164 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0007013069.mp3
# 165 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0007057303.mp3
# 166 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0007067293.mp3
# 167 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0007147603.mp3
# 168 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0007439502.mp3
# 169 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0007443823.mp3
# 170 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0007840454.mp3
# 171 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008222676.mp3
# 172 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008276791.mp3
# 173 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008340316.mp3
# 174 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008363839.mp3
# 175 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008401073.mp3
# 176 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008575372.mp3
# 177 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008644609.mp3
# 178 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008675527.mp3
# 179 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008684922.mp3
# 180 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0008972801.mp3
# 181 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009010830.mp3
# 182 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009188643.mp3
# 183 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009202768.mp3
# 184 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009208842.mp3
# 185 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009213083.mp3
# 186 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009378909.mp3
# 187 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009729892.mp3
# 188 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009845271.mp3
# 189 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009845275.mp3
# 190 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009845276.mp3
# 191 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009897495.mp3
# 192 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0009904717.mp3
# 193 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010085729.mp3
# 194 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010344415.mp3
# 195 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010392442.mp3
# 196 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010465830.mp3
# 197 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010482550.mp3
# 198 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010487769.mp3
# 199 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010489498.mp3
# 200 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010501618.mp3
# 201 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010617945.mp3
# 202 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010694663.mp3
# 203 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0010900969.mp3
# 204 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011104152.mp3
# 205 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011354857.mp3
# 206 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011560587.mp3
# 207 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011564855.mp3
# 208 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011574534.mp3
# 209 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011575842.mp3
# 210 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011739779.mp3
# 211 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011786799.mp3
# 212 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011821215.mp3
# 213 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011869625.mp3
# 214 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011916674.mp3
# 215 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011930865.mp3
# 216 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011950450.mp3
# 217 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011957429.mp3
# 218 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011997914.mp3
# 219 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0011999773.mp3
# 220 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012041920.mp3
# 221 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012202513.mp3
# 222 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012331779.mp3
# 223 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012396528.mp3
# 224 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012534566.mp3
# 225 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012601428.mp3
# 226 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012742379.mp3
# 227 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012798988.mp3
# 228 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0012846850.mp3
# 229 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0013101577.mp3
# 230 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0013235939.mp3
# 231 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0013350034.mp3
# 232 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0013389935.mp3
# 233 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0013590244.mp3
# 234 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0013633209.mp3
# 235 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0013800071.mp3
# 236 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0013914319.mp3
# 237 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0014586720.mp3
# 238 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0014650360.mp3
# 239 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0015005100.mp3
# 240 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0015028144.mp3
# 241 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0015680193.mp3
# 242 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0015742096.mp3
# 243 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0015934550.mp3
# 244 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0016972827.mp3
# 245 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0017797643.mp3
# 246 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0018024152.mp3
# 247 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0018029465.mp3
# 248 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0018031959.mp3
# 249 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0018450519.mp3
# 250 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0018617125.mp3
# 251 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0018651126.mp3
# 252 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0026158301.mp3
# 253 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0026727455.mp3
# 254 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0026753600.mp3
# 255 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0026753827.mp3
# 256 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0026795261.mp3
# 257 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0027002641.mp3
# 258 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0027035970.mp3
# 259 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0027048677.mp3
# 260 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0027159893.mp3
# 261 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0027478016.mp3
# 262 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0028220133.mp3
# 263 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0028445777.mp3
# 264 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0028495262.mp3
# 265 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0028617657.mp3
# 266 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0028627699.mp3
# 267 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0028648077.mp3
# 268 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0029065626.mp3
# 269 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0029492542.mp3
# 270 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0029874624.mp3
# 271 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0030484925.mp3
# 272 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0030487841.mp3
# 273 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0031544440.mp3
# 274 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0031922089.mp3
# 275 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0031996897.mp3
# 276 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0032061241.mp3
# 277 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0032181833.mp3
# 278 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0032235381.mp3
# 279 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0032332758.mp3
# 280 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0032405040.mp3
# 281 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0032892262.mp3
# 282 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0033397838.mp3
# 283 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0033415296.mp3
# 284 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0033443279.mp3
# 285 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0033841575.mp3
# 286 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0033940994.mp3
# 287 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0033958450.mp3
# 288 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0034125967.mp3
# 289 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0034555338.mp3
# 290 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0034988131.mp3
# 291 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\MT0036368550.mp3
# 292 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\muhabbet_bagina_girdim.mp3
# 293 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\murat-kursun-erik-dali-part.mp3
# 294 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\mustafa_sandal_aya_benzer.mp3
# 295 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\omer-faruk-bostan-erik-dali-part.mp3
# 296 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\osman_aga_seferad.mp3
# 297 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\ovalar_gurup_yol.mp3
# 298 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\panara_gel_ki_gorem_cesitli_sanatci.mp3
# 299 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\rakkas_sezen_aksu.mp3
# 300 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\salinda_gel_orhan_hak_almaz.mp3
# 301 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\samsak_doveci_gurup_lacin.mp3
# 302 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\sendeki_kaslar_suzan_kardes.mp3
# 303 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\sevinc_sarivea_yandirgin_kalbimi_aman.mp3
# 304 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\sigaramin_duman_meski_fasil.mp3
# 305 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\siverek_asmasiyam_ibrahim_tatlises.mp3
# 306 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\son_verdim_kalbimin_issine_seyyal_taner.mp3
# 307 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\sozlu_halay.mp3
# 308 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\su_gelen_atlimidir.mp3
# 309 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\su_samsunun_evleri_imara.mp3
# 310 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\tatli_dile_guler_yuze_neset_ertas.mp3
# 311 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\tridine_bandim_kubat.mp3
# 312 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\uskudara_gideriken.mp3
# 313 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\uyu_demeye_geldim_melda_kuyucu.mp3
# 314 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\vardar_ovasi_fasli_beyoglu.mp3
# 315 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\vay_surmeli_surmeli.mp3
# 316 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\yangin_olur_biz_yangina_gideriz_fasli_beyoglu.mp3
# 317 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\yar_saclarin_lule_lule_nesrin_sipahi.mp3
# 318 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\yemeninde_hare_var_meski_fasil.mp3
# 319 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\yola_ciktim_mardine_berdan.mp3
# 320 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\yuksek_yuksek_tepelere.mp3
# 321 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\yuru_dilber_yuru_fasil.mp3
# 322 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\zeytin_yapragi_yesil_zara.mp3
# 323 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\happy\zuhtu_sumer_ezgu.mp3
# 324 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\ajda-pekkan-ya-sonra- Part.mp3
# 325 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\aklim_hep_sende.mp3
# 326 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\alp_ersonmez_burada_yarali_biri_var.mp3
# 327 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\aysegul_aldinc_kucuk_seyler.mp3
# 328 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\ayten_alpman_erkekler_aglamaz.mp3
# 329 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\bana_ellerini_ver_ozdemir_erdogan.mp3
# 330 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\basak_yavuz_gidersen.mp3
# 331 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\ben-yoruldum-hayat-part-cinar-cetinkaya-part.mp3
# 332 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\ben_varim_kursat.mp3
# 333 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\berguzar_korel_kaybolan_yillar.mp3
# 334 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\birsen-tezer-bilsen-part.mp3
# 335 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\birsen_tezer_ciglik_cigliga.mp3
# 336 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\birsen_tezer_di_gel_yanima.mp3
# 337 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\Birsen_tezer_istanbul.mp3
# 338 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\birsen_tezer_sarkicinin_sarkicisi.mp3
# 339 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\birsen_tezer_seher_vahti.mp3
# 340 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\bulent_ortacgil_sana_geldim.mp3
# 341 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\bulent_ortacgil_sensiz_olmaz.mp3
# 342 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\bulent_ortacgil_yagmur.mp3
# 343 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\bulent_ortacgil_yuzunu_dokme_kucuk_kiz.mp3
# 344 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\cem_ozkan_don_bana.mp3
# 345 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\cigdem_erken_cakmak.mp3
# 346 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\cigdem_erken_laleler.mp3
# 347 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\demir_demircan_aci_nefes.mp3
# 348 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\demir_demirkan_doldur_kadehleri.mp3
# 349 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\duman_elleri_ellerime.mp3
# 350 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\dusundukce_selen_gulun.mp3
# 351 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\elvan_gunaydin.mp3
# 352 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\enbe_orkestrasi_hikaye.mp3
# 353 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\eren_cilgin_mavi_yalan.mp3
# 354 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\erol_evgin_bir_ilk_bahar_sabahi.mp3
# 355 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\ezginin_gunlugu_ask_yuzunden.mp3
# 356 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\ezginin_gunlugu_kiyisiz_deniz.mp3
# 357 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\ezgini_gunlugu_mutlu_son.mp3
# 358 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\feridun_duzagac_sevgi.mp3
# 359 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikret_kizilok_basbasa.mp3
# 360 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikret_kizilok_ben_gidersem.mp3
# 361 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikret_kizilok_bosuna.mp3
# 362 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikret_kizilok_farketmeden.mp3
# 363 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikret_kizilok_gecenin_ucunde.mp3
# 364 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikret_kizilok_gidiyorsun.mp3
# 365 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikret_kizilok_gonul.mp3
# 366 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikret_kizilok_guzel_ne_guzel_olmussun.mp3
# 367 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\fikrimin-ince-gulu-tamer-zeytinoglu-part.mp3
# 368 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\julide_ozcelik_bugun_neden_gelmedin.mp3
# 369 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\julide_ozcelik_esitiz_eninde_sonunda.mp3
# 370 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\julide_ozcelik_kara_toprak.mp3
# 371 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\julide_ozcelik_kimse_bilmez.mp3
# 372 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\julide_ozcelik_siradan_bir_gun.mp3
# 373 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\julide_ozcelik_yalan_dunya.mp3
# 374 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\julide_ozcelik_zaman.mp3
# 375 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\kelebek_cigdem_Erkan.mp3
# 376 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\kendinle_kalirsin_julide_ozcelik.mp3
# 377 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\kimseye_etmem_sikayet.mp3
# 378 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\kimse_bilmez_kursat_basar.mp3
# 379 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\kirac_kalbin_tek_arkadasi.mp3
# 380 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\mabel_matis_supheli_sarkinin_sairi.mp3
# 381 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\mahsar_alanson_benim_hala_umudum_var.mp3
# 382 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\mazi_kalbimde_bir_yaradir_dilek_turkan.mp3
# 383 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\mehmet_gureli_kimse_bilmez.mp3
# 384 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\mert_royfe_zaman.mp3
# 385 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\mfo_bodrum_bodrum.mp3
# 386 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\mor_ve_otesi_bisiklet.mp3
# 387 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000054705.mp3
# 388 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000092267.mp3
# 389 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000202045.mp3
# 390 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000203193.mp3
# 391 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000218346.mp3
# 392 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000235880.mp3
# 393 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000336135.mp3
# 394 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000348553.mp3
# 395 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000369789.mp3
# 396 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000460427.mp3
# 397 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000522789.mp3
# 398 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000550961.mp3
# 399 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000636335.mp3
# 400 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000661847.mp3
# 401 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000698081.mp3
# 402 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000711493.mp3
# 403 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000746822.mp3
# 404 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000762097.mp3
# 405 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000821772.mp3
# 406 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000888329.mp3
# 407 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000901959.mp3
# 408 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000922312.mp3
# 409 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0000980148.mp3
# 410 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001058887.mp3
# 411 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001109401.mp3
# 412 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001195535.mp3
# 413 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001394087.mp3
# 414 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001438043.mp3
# 415 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001494812.mp3
# 416 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001511433.mp3
# 417 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001594582.mp3
# 418 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001624303.mp3
# 419 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001641228.mp3
# 420 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001661022.mp3
# 421 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001676671.mp3
# 422 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001768550.mp3
# 423 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001870847.mp3
# 424 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001877603.mp3
# 425 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001942272.mp3
# 426 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0001980613.mp3
# 427 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002124238.mp3
# 428 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002132088.mp3
# 429 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002448379.mp3
# 430 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002674708.mp3
# 431 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002698827.mp3
# 432 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002714805.mp3
# 433 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002811975.mp3
# 434 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002834532.mp3
# 435 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0002846256.mp3
# 436 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0003022328.mp3
# 437 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0003025046.mp3
# 438 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0003280103.mp3
# 439 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0003366948.mp3
# 440 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0003454112.mp3
# 441 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0003710207.mp3
# 442 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0003778826.mp3
# 443 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0003956612.mp3
# 444 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004036096.mp3
# 445 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004089549.mp3
# 446 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004093767.mp3
# 447 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004274911.mp3
# 448 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004331116.mp3
# 449 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004537445.mp3
# 450 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004584067.mp3
# 451 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004759106.mp3
# 452 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004833310.mp3
# 453 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004850690.mp3
# 454 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004867564.mp3
# 455 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0004911454.mp3
# 456 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005074629.mp3
# 457 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005091539.mp3
# 458 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005129157.mp3
# 459 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005261375.mp3
# 460 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005285696.mp3
# 461 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005550441.mp3
# 462 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005608787.mp3
# 463 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005656534.mp3
# 464 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005695311.mp3
# 465 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005798527.mp3
# 466 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005850999.mp3
# 467 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005884980.mp3
# 468 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0005987148.mp3
# 469 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006037085.mp3
# 470 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006107326.mp3
# 471 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006117018.mp3
# 472 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006164654.mp3
# 473 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006254062.mp3
# 474 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006352493.mp3
# 475 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006769480.mp3
# 476 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006955716.mp3
# 477 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0006983241.mp3
# 478 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007039041.mp3
# 479 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007053424.mp3
# 480 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007064420.mp3
# 481 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007087238.mp3
# 482 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007107079.mp3
# 483 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007119529.mp3
# 484 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007186714.mp3
# 485 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007207968.mp3
# 486 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007232134.mp3
# 487 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007342701.mp3
# 488 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007453719.mp3
# 489 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007556029.mp3
# 490 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007766156.mp3
# 491 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0007833171.mp3
# 492 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0008167476.mp3
# 493 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0008342962.mp3
# 494 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0008665212.mp3
# 495 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0008686594.mp3
# 496 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0009075362.mp3
# 497 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0009185069.mp3
# 498 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0009289348.mp3
# 499 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0009741521.mp3
# 500 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0009769814.mp3
# 501 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0009991160.mp3
# 502 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010203716.mp3
# 503 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010485603.mp3
# 504 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010665248.mp3
# 505 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010707508.mp3
# 506 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010758927.mp3
# 507 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010810859.mp3
# 508 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010818060.mp3
# 509 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010842738.mp3
# 510 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010855214.mp3
# 511 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010965655.mp3
# 512 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010979481.mp3
# 513 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010984486.mp3
# 514 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0010998105.mp3
# 515 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0011051663.mp3
# 516 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0011250965.mp3
# 517 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0011376343.mp3
# 518 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0011380622.mp3
# 519 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0011702301.mp3
# 520 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\relax\MT0011862487.mp3
# ...
# 795 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0004842694.mp3
# 796 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0004922692.mp3
# 797 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0004978135.mp3
# 798 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0004988249.mp3
# 799 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005001966.mp3
# 800 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005115042.mp3
# 801 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005155949.mp3
# 802 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005157391.mp3
# 803 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005171805.mp3
# 804 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005217073.mp3
# 805 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005221680.mp3
# 806 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005253065.mp3
# 807 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005262725.mp3
# 808 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005270263.mp3
# 809 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005520274.mp3
# 810 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005963165.mp3
# 811 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0005981667.mp3
# 812 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0006159067.mp3
# 813 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0006171393.mp3
# 814 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0006397809.mp3
# 815 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0006400514.mp3
# 816 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0006410285.mp3
# 817 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0006555035.mp3
# 818 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0006672286.mp3
# 819 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0006919273.mp3
# 820 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007043936.mp3
# 821 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007099407.mp3
# 822 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007265208.mp3
# 823 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007338724.mp3
# 824 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007349999.mp3
# 825 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007372035.mp3
# 826 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007410187.mp3
# 827 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007438571.mp3
# 828 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007477802.mp3
# 829 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007497706.mp3
# 830 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007550652.mp3
# 831 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007583962.mp3
# 832 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007610380.mp3
# 833 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007652281.mp3
# 834 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007728545.mp3
# 835 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007860263.mp3
# 836 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0007914044.mp3
# 837 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008007368.mp3
# 838 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008018703.mp3
# 839 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008077089.mp3
# 840 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008170600.mp3
# 841 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008399774.mp3
# 842 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008493270.mp3
# 843 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008716237.mp3
# 844 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008718991.mp3
# 845 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008841966.mp3
# 846 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008979040.mp3
# 847 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0008999898.mp3
# 848 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009169626.mp3
# 849 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009182700.mp3
# 850 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009220462.mp3
# 851 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009368615.mp3
# 852 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009385684.mp3
# 853 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009437817.mp3
# 854 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009521580.mp3
# 855 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009619048.mp3
# 856 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009628869.mp3
# 857 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009693151.mp3
# 858 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0009996318.mp3
# 859 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0010375510.mp3
# 860 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0010468178.mp3
# 861 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0010585105.mp3
# 862 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0010739708.mp3
# 863 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0010804974.mp3
# 864 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0010850805.mp3
# 865 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011032905.mp3
# 866 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011066228.mp3
# 867 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011095825.mp3
# 868 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011158114.mp3
# 869 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011230792.mp3
# 870 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011308097.mp3
# 871 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011391187.mp3
# 872 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011398970.mp3
# 873 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011440705.mp3
# 874 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011594970.mp3
# 875 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011612883.mp3
# 876 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011667212.mp3
# 877 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011836290.mp3
# 878 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011894681.mp3
# 879 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011899302.mp3
# 880 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0011969592.mp3
# 881 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0012020062.mp3
# 882 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0012292188.mp3
# 883 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0012317309.mp3
# 884 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0012634038.mp3
# 885 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0012675695.mp3
# 886 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0013044535.mp3
# 887 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0013080259.mp3
# 888 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0013161246.mp3
# 889 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0013166908.mp3
# 890 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0013173557.mp3
# 891 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0013219857.mp3
# 892 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0013416300.mp3
# 893 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014046859.mp3
# 894 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014050974.mp3
# 895 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014118699.mp3
# 896 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014192212.mp3
# 897 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014584473.mp3
# 898 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014665667.mp3
# 899 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014737299.mp3
# 900 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014794891.mp3
# 901 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0014804830.mp3
# 902 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0015004289.mp3
# 903 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0015510419.mp3
# 904 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0015514030.mp3
# 905 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0015599764.mp3
# 906 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0015664499.mp3
# 907 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0015665796.mp3
# 908 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0015682649.mp3
# 909 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0015715008.mp3
# 910 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0026330298.mp3
# 911 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0026690204.mp3
# 912 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0026905937.mp3
# 913 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0028698324.mp3
# 914 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0028947009.mp3
# 915 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0029861029.mp3
# 916 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0029877658.mp3
# 917 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0030247926.mp3
# 918 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0030252676.mp3
# 919 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0030304982.mp3
# 920 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0030321464.mp3
# 921 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0030400613.mp3
# 922 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0030422114.mp3
# 923 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0031693432.mp3
# 924 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0031951901.mp3
# 925 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0033159895.mp3
# 926 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0033177286.mp3
# 927 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0033226848.mp3
# 928 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0033317646.mp3
# 929 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0033345959.mp3
# 930 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0034136847.mp3
# 931 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0034574251.mp3
# 932 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0034982187.mp3
# 933 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0035007057.mp3
# 934 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0035316286.mp3
# 935 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\MT0040033011.mp3
# 936 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\muhur_gozlum_cafer_nazlibas.mp3
# 937 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\nem_kaldi_gonen_molla.mp3
# 938 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\nikah_masasi_umit_besen.mp3
# 939 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\niye_cattin_kaslarini_umit_ates.mp3
# 940 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\odam_kirec_tutmuyor_gonen_molla.mp3
# 941 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\olumsuz_sevdim_arif_susam.mp3
# 942 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\oy_beni_vurun_vurun_huseyin_ay.mp3
# 943 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\o_yar_gelir.mp3
# 944 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\sarkilara_sordum_soylemediler_emel_sayin.mp3
# 945 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\sarkilar_seni_soyler_zeki_muren.mp3
# 946 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\seher_vaki_evinize_canan_cal.mp3
# 947 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\seher_yildizi.mp3
# 948 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\senede_bir_gun_zeki_muren.mp3
# 949 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\sen_benden_gittin_gideli_erkan_ogur.mp3
# 950 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\sen_gelmez_oldun_piyano.mp3
# 951 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\sevmekten_kim_usanir_hamiyet_yuceses.mp3
# 952 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\sevmekten_kim_usanir_muzzeyen_senar.mp3
# 953 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\sonu_yok_bu_askin_funda_arar.mp3
# 954 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\soyleyemem_derdimi_zeki_muren.mp3
# 955 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\suzan_suzi_cengiz_ozkan.mp3
# 956 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\suzan_suzi_incesaz.mp3
# 957 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\su_kislanin_kapisina_orhan_hakalmaz.mp3
# 958 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\unutmamam_seni_zeki_muren.mp3
# 959 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\unutmasin_hudai_aksu.mp3
# 960 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\unutma_beni_esmeray.mp3
# 961 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\uyan_sunam.mp3
# 962 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\uzun_ince_bir_yoldayim.mp3
# 963 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\vazgectim_ara_dinkjian.mp3
# 964 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\vazgectim_serkan_cagri.mp3
# 965 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\veda_busesi_zeki_muren.mp3
# 966 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\vurgun_muazzez_abaci.mp3
# 967 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\yarim_senden_ayrilali_erkan_ogur.mp3
# 968 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\yazimi_kisa_cevirdin.mp3
# 969 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\yazimi_kisa_cevirdin_muhlis_berberoglu.mp3
# 970 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\yemen_turkusu.mp3
# 971 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\yol_ver_daglar_arif_sag.mp3
# 972 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\yuce_dag_basinda_yanar_bir_isik_sirri_lacin.mp3
# 973 D:/UM/Project/Mozartify/project/Datasets/audio/trimmed_audio\sad\zuluf_dokmus_yuze_feyzi_yagci.mp3

# %% [markdown]
# ## 2. Data Augmentation

# %%
#add noise
def add_noise(data):
    wn = np.random.normal(0, 1, len(data))
    return np.where(data != 0.0, data.astype('float64') + 0.02 * wn, 0.0).astype(np.float32)

# %%
def time_shift(data, shift):
    # shift：shifting lenth
    return np.roll(data, int(shift))

# %%
for file in file_dir25:
    m = os.path.basename(os.path.dirname(file))
    f_noise_dir = os.path.join("D:/UM/Project/Mozartify/project/Datasets/audio/noise", m)
    f_shift_dir = os.path.join("D:/UM/Project/Mozartify/project/Datasets/audio/TimeShift", m)

    # Create directories if they do not exist
    os.makedirs(f_noise_dir, exist_ok=True)
    os.makedirs(f_shift_dir, exist_ok=True)

    f_noise = os.path.join(f_noise_dir, 'noise_' + os.path.basename(file))
    f_shift = os.path.join(f_shift_dir, 'shift_' + os.path.basename(file))

    data, sr = librosa.load(file)
    data_noise = add_noise(data)
    data_shift = time_shift(data, shift=sr)

    wavfile.write(f_noise, sr, data_noise)
    wavfile.write(f_shift, sr, data_shift)

# %%
dir_noise = "D:/UM/Project/Mozartify/project/Datasets/audio/Noise/"
data_noise = os.listdir(dir_noise)
file_noise = []
count = 0

for mooddir in data_noise:
    if(not r'.' in mooddir):
        moodDirName = os.path.join(dir_noise,mooddir)
        mooddir=np.array(os.listdir(moodDirName))
        for audio in mooddir:
            if(audio[-3:]=='mp3'):
                count+=1
                fn=os.path.join(moodDirName,audio)
                file_noise.append(fn)

# %%
duration_noise = []
for i in range(len(file_noise)):
    y,sr = librosa.load(file_noise[i])
    d = librosa.get_duration(y=y,sr=sr)
    duration_noise.append(d)

# %%
for i in range(len(duration_noise)):
    if duration_noise[i]!=25.5:
        print(i,duration_noise[i])
# Out:
# 235 10.08
# 648 9.783990929705215

# %%
dir_shift = "D:/UM/Project/Mozartify/project/Datasets/audio/TimeShift/"
data_shift = os.listdir(dir_shift)
file_shift = []

for mooddir in data_shift:
    if(not r'.' in mooddir):
        moodDirName = os.path.join(dir_shift,mooddir)
        mooddir=np.array(os.listdir(moodDirName))
        for audio in mooddir:
            if(audio[-3:]=='mp3'):
                fn=os.path.join(moodDirName,audio)
                file_shift.append(fn)

# %%
duration_shift = []
for i in range(len(file_shift)):
    y,sr = librosa.load(file_shift[i])
    d = librosa.get_duration(y=y,sr=sr)
    duration_shift.append(d)

# %%
for i in range(len(duration_shift)):
    if duration_shift[i]!=25.5:
        print(i,duration_shift[i])
# Out:
# 235 10.08
# 648 9.783990929705215

# %% [markdown]
# ## 4. 1D Feature Extraction

# %%
import re
def key_scale_finder(file):
    pitches = ['C','C#','D','D#','E','F','F#','G','G#','A','A#','B']
    y,sr = librosa.load(file)
    key = librosa.feature.chroma_stft(y=y,sr=sr).sum(axis=1).argmax()
    if re.search("\#$",pitches[key]):
        scale = "minor"
    else:
        scale = "major"
    return scale,pitches[key]

def feature_1d(file):
    try:
        y,sr = librosa.load(file)
    except:
        print('No such file')
        quit()
    
    f = [] 
    
    # tempo
    tempo = librosa.beat.tempo(y=y,sr=sr)[0]
    f.append(tempo)  
    
    # RMS
    #S, phase = librosa.magphase(librosa.stft(y))
    rms = librosa.feature.rms(y=y)
    rms_mean = np.mean(rms)
    rms_var = np.var(rms)
    f.append(rms_mean)
    f.append(rms_var)
    
    # chroma features
    chroma = librosa.feature.chroma_stft(y=y,sr=sr)
    chroma_mean = np.mean(chroma)
    chroma_var = np.var(chroma)
    f.append(chroma_mean)
    f.append(chroma_var)
    
    # spectral centroid
    centroid = librosa.feature.spectral_centroid(y=y)
    centroid_mean = np.mean(centroid)
    centroid_var = np.var(centroid)
    f.append(centroid_mean)
    f.append(centroid_var)
    
    # spectral rolloff
    rolloff = librosa.feature.spectral_rolloff(y=y+0.01, sr=sr)
    rolloff_mean = np.mean(rolloff)
    rolloff_var = np.var(rolloff)
    f.append(rolloff_mean)
    f.append(rolloff_var)
    
    # zero crossing rate
    zcr = librosa.feature.zero_crossing_rate(y=y)
    zcr_mean = np.mean(zcr)
    zcr_var = np.var(zcr)
    f.append(zcr_mean)
    f.append(zcr_var)
    
    # tonnetz
    tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
    tonnetz_mean = np.mean(tonnetz)
    tonnetz_var  = np.var(tonnetz)
    f.append(tonnetz_mean)
    f.append(tonnetz_var)
    
    #mel
    s = librosa.feature.melspectrogram(y=y, sr=sr)
    mel = librosa.amplitude_to_db(s, ref=np.max)
    mel_mean = np.mean(mel)
    mel_var = np.var(mel)
    f.append(mel_mean)
    f.append(mel_var)
    
    #mfcc
    mfcc = librosa.feature.mfcc(y=y,sr=sr,n_mfcc=20)
    m = len(mfcc)
    mfcc_mean = np.zeros((m,))
    mfcc_var = np.zeros((m,))
    for i in range(len(mfcc)):
        mfcc_mean[i] = np.mean(mfcc[i])
        mfcc_var[i]= np.var(mfcc[i])
        f.append(mfcc_mean[i])
        f.append(mfcc_var[i])
    
    return np.array(f)

# %%
#Extract Key and Scale
noise_key = []
noise_scale = []
for i in range(len(file_noise)):
    noise_key.append(key_scale_finder(file_noise[i])[1])
    noise_scale.append(key_scale_finder(file_noise[i])[0])

# %%
#Feature Vectors
noise_features = np.zeros((len(file_noise),55))
for i in range(0,len(file_noise)):
    noise_features[i] = feature_1d(file_noise[i])

# %%
# Label the mood
mood_noise = []
for i in range(len(file_noise)):
    m = os.path.basename(os.path.dirname(file_noise[i]))
    mood_noise.append(m)

# %%
shift_key = []
shift_scale = []
for i in range(len(file_shift)):
    shift_key.append(key_scale_finder(file_shift[i])[1])
    shift_scale.append(key_scale_finder(file_shift[i])[0])

# %%
#Feature Vectors
shift_features = np.zeros((len(file_shift),55))
for i in range(0,len(file_shift)):
    shift_features[i] = feature_1d(file_shift[i])

# %%
# Label the mood
mood_shift = []
for i in range(len(file_shift)):
    m = os.path.basename(os.path.dirname(file_shift[i]))
    mood_shift.append(m)

# %%
# Store 15 features to data frame
col_name = ['tempo','rms_mean','rms_var','chroma_mean','chroma_var',
            'centroid_mean','centroid_var','rolloff_mean','roll_off_var',
            'zcr_mean','zcr_var','tonnetz_mean', 'tonnetz_var', 'mel_mean', 'mel_var']
# Store 20 mfccs mean and var to data frame
mfccs_col_name = []
for i in range(0,20):
    mfccs_col_name.append("mfcc_mean_"+str(i+1))
    mfccs_col_name.append("mfcc_var_"+str(i+1))

# %%
# Create a data frame to store all the data
features_noise = pd.DataFrame()

# %%
# Store file name
features_noise['file'] = file_noise
# Store key and scale
features_noise['scale'] = noise_scale
features_noise['key'] = noise_key
# Store 13 features and 20 mfccs
for i in range(len(col_name)):
    features_noise[col_name[i]] = noise_features[:,i]
for i in range(len(mfccs_col_name)):
    features_noise[mfccs_col_name[i]] = noise_features[:,i+15]
# Store mood
features_noise['mood'] = mood_noise

# %%
features_noise
# Out:
#                                                   file  scale key       tempo  \
# 0    D:/UM/Project/Mozartify/project/Datasets/audio...  major   D  135.999178
# 1    D:/UM/Project/Mozartify/project/Datasets/audio...  major   E  107.666016
# 2    D:/UM/Project/Mozartify/project/Datasets/audio...  major   A   99.384014
# 3    D:/UM/Project/Mozartify/project/Datasets/audio...  major   A  107.666016
# 4    D:/UM/Project/Mozartify/project/Datasets/audio...  major   E  129.199219
# ..                                                 ...    ...  ..         ...
# 968  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A  151.999081
# 969  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  G#   89.102909
# 970  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E   99.384014
# 971  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A   99.384014
# 972  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  F#  103.359375
#
#      rms_mean   rms_var  chroma_mean  chroma_var  centroid_mean  \
# 0    0.172551  0.003279     0.346737    0.097540    2966.634004
# 1    0.108430  0.000697     0.425311    0.088677    3245.481036
# 2    0.242929  0.010846     0.438916    0.083680    3349.734719
# 3    0.122461  0.002094     0.429079    0.077916    3441.083045
# 4    0.194006  0.003910     0.276141    0.085043    2714.529319
# ..        ...       ...          ...         ...            ...
# 968  0.099292  0.000553     0.302301    0.086560    3586.618854
# 969  0.086727  0.001535     0.288060    0.082760    3649.597341
# 970  0.079354  0.000271     0.249582    0.087047    3687.129803
# 971  0.074790  0.000973     0.291124    0.089676    3945.450852
# 972  0.058689  0.000631     0.256780    0.083459    4186.240709
#
#       centroid_var  ...  mfcc_var_16  mfcc_mean_17  mfcc_var_17  mfcc_mean_18  \
# 0    269376.017250  ...    85.576714     -1.930645    56.159031     -0.892971
# 1    184365.866922  ...    27.379467     -5.753342    32.791855     -4.232408
# 2    592307.581520  ...    59.253696     -4.593424    57.105923     -2.326811
# 3    165997.534587  ...    29.263926     -2.092536    28.378841     -3.750346
# 4    122088.557930  ...    22.606628     -7.715428    26.561018     -3.081796
# ..             ...  ...          ...           ...          ...           ...
# 968  118513.526362  ...    25.648636    -11.969786    31.615791     -8.434127
# 969  268761.677383  ...    24.422441    -10.237507    20.169052     -8.180056
# 970   88172.109414  ...    22.693632     -1.819579    22.148537     -2.206744
# 971  272248.199393  ...    26.464180     -9.677834    28.049032     -9.241619
# 972  206966.597150  ...    26.027870     -4.082352    37.917431     -1.456431
#
#      mfcc_var_18  mfcc_mean_19  mfcc_var_19  mfcc_mean_20  mfcc_var_20   mood
# 0      51.551453      0.633405    47.186474      0.253610    38.859661  happy
# 1      35.934994     -1.325320    49.086235     -1.749682    67.460434  happy
# 2      42.335182     -3.384727    42.804070     -0.737544    61.920296  happy
# 3      26.634878     -5.963063    27.701960     -6.120047    26.094809  happy
# 4      38.821686     -1.843145    54.758949      4.226146    58.505424  happy
# ..           ...           ...          ...           ...          ...    ...
# 968    28.832972    -11.089932    23.921122    -12.584082    28.737524    sad
# 969    21.755917     -9.295341    18.762970    -10.592243    30.263374    sad
# 970    27.014732      1.092161    37.564590      2.067389    34.046097    sad
# 971    24.549885     -9.959146    28.012188    -10.346671    40.555420    sad
# 972    32.269768     -2.180017    30.874439     -4.235230    33.675522    sad
#
# [973 rows x 59 columns]

# %%
# Create the Excel file
pd.ExcelWriter('D:/UM/Project/Mozartify/project/Datasets/Features/Features1D/Features_noise.xlsx')

# %%
# Store the Feature into excel file
features_noise.to_excel('D:/UM/Project/Mozartify/project/Datasets/Features/Features1D/Features_noise.xlsx')

# %%
# Create a data frame to store all the data
features_shift = pd.DataFrame()

# %%
# Store file name
features_shift['file'] = file_shift
# Store key and scale
features_shift['scale'] = shift_scale
features_shift['key'] = shift_key
# Store 13 features and 20 mfccs
for i in range(len(col_name)):
    features_shift[col_name[i]] = shift_features[:,i]
for i in range(len(mfccs_col_name)):
    features_shift[mfccs_col_name[i]] = shift_features[:,i+15]
# Store mood
features_shift['mood'] = mood_shift

# %%
features_shift
# Out:
#                                                   file  scale key       tempo  \
# 0    D:/UM/Project/Mozartify/project/Datasets/audio...  major   D  135.999178
# 1    D:/UM/Project/Mozartify/project/Datasets/audio...  major   E  107.666016
# 2    D:/UM/Project/Mozartify/project/Datasets/audio...  major   A   99.384014
# 3    D:/UM/Project/Mozartify/project/Datasets/audio...  major   A  112.347147
# 4    D:/UM/Project/Mozartify/project/Datasets/audio...  major   E  129.199219
# ..                                                 ...    ...  ..         ...
# 968  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A  151.999081
# 969  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  G#   89.102909
# 970  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E   99.384014
# 971  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A   99.384014
# 972  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  F#   95.703125
#
#      rms_mean   rms_var  chroma_mean  chroma_var  centroid_mean  centroid_var  \
# 0    0.171162  0.003351     0.340845    0.097614    2289.203108  3.396879e+05
# 1    0.106434  0.000724     0.414449    0.089709    2128.873013  3.900859e+05
# 2    0.241991  0.010835     0.435087    0.083844    2979.436280  1.126172e+06
# 3    0.120569  0.002160     0.421653    0.079912    2884.974018  1.293321e+05
# 4    0.192869  0.003973     0.272747    0.084913    2147.226175  1.973454e+05
# ..        ...       ...          ...         ...            ...           ...
# 968  0.097108  0.000583     0.294316    0.088250    1996.638353  5.530875e+05
# 969  0.083857  0.001617     0.272484    0.085090    1331.675571  1.541154e+05
# 970  0.076663  0.000291     0.237296    0.089185    1681.076015  2.767160e+05
# 971  0.071239  0.001091     0.263241    0.092150    2075.791687  2.096039e+05
# 972  0.054446  0.000716     0.226684    0.087591    1858.374251  1.414966e+05
#
#      ...  mfcc_var_16  mfcc_mean_17  mfcc_var_17  mfcc_mean_18  mfcc_var_18  \
# 0    ...    97.515526     -3.539253    71.415993     -0.424872    66.437180
# 1    ...    37.903477     -9.216166    46.307808     -1.430186    50.143211
# 2    ...    67.475204     -6.002207    66.501785     -1.109421    48.929623
# 3    ...    33.690018     -4.149460    37.224216     -3.795806    32.814350
# 4    ...    28.748222    -10.841578    36.262440     -0.469117    47.630962
# ..   ...          ...           ...          ...           ...          ...
# 968  ...    52.284241    -18.933998    71.058098     -6.168517    61.867592
# 969  ...    37.903763    -11.966993    43.538395     -5.346477    40.368793
# 970  ...    46.474285     -5.677488    40.483074     -3.268615    47.944653
# 971  ...    45.625221    -16.519905    45.574238    -11.216208    48.625031
# 972  ...    46.052235     -5.974515    78.356987      2.442869    74.308540
#
#      mfcc_mean_19  mfcc_var_19  mfcc_mean_20  mfcc_var_20   mood
# 0       -0.199554    59.399525      0.886875    47.189739  happy
# 1       -3.562091    65.681473      1.210580    85.589287  happy
# 2       -4.635880    50.368835      0.668790    79.389671  happy
# 3       -8.422532    32.291790     -6.022736    30.629898  happy
# 4       -4.169499    60.776985      6.336962    64.402382  happy
# ..            ...          ...           ...          ...    ...
# 968    -16.978498    55.321728    -14.182650    64.533455    sad
# 969    -10.921440    37.538857    -15.324995    56.659206    sad
# 970      1.989569    70.061569      5.450746    69.814407    sad
# 971    -15.720529    54.754559    -15.151942    68.066071    sad
# 972     -2.236240    73.018707     -5.541601    73.778122    sad
#
# [973 rows x 59 columns]

# %%
# Create the Excel file
pd.ExcelWriter('D:/UM/Project/Mozartify/project/Datasets/Features/Features1D/Features_shift.xlsx')

# %%
# Store the Feature into excel file
features_shift.to_excel('D:/UM/Project/Mozartify/project/Datasets/Features/Features1D/Features_shift.xlsx')

# %% [markdown]
# ## 4. 2D Feature Extraction

# %%
n_noise = len(file_noise)
spec_noise = np.empty([n_noise, 1025, 1099])
mfccs_noise = np.empty([n_noise, 20, 1099])
mel_noise = np.empty([n_noise, 128, 1099])

n_shift = len(file_shift)
spec_shift = np.empty([n_shift, 1025, 1099])
mfccs_shift = np.empty([n_shift, 20, 1099])
mel_shift = np.empty([n_shift, 128, 1099])

# %%
def feature2d(file, max_frames=1099):
    try:
        y, sr = librosa.load(file)
    except:
        print('No such file')
        return None, None, None

    # Spectrogram
    stft = librosa.stft(y)
    stft_db = librosa.amplitude_to_db(abs(stft))
    spec = librosa.util.fix_length(stft_db, size=max_frames, axis=1)

    # MFCC
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
    mfccs = librosa.util.fix_length(mfccs, size=max_frames, axis=1)

    # Mel
    s = librosa.feature.melspectrogram(y=y, sr=sr)
    mel = librosa.amplitude_to_db(s, ref=np.max)
    mel = librosa.util.fix_length(mel, size=max_frames, axis=1)

    return spec, mfccs, mel

# Initialize arrays for noise files
n_noise = len(file_noise)
spec_noise = np.empty([n_noise, 1025, 1099])
mfccs_noise = np.empty([n_noise, 20, 1099])
mel_noise = np.empty([n_noise, 128, 1099])

# Initialize arrays for shift files
n_shift = len(file_shift)
spec_shift = np.empty([n_shift, 1025, 1099])
mfccs_shift = np.empty([n_shift, 20, 1099])
mel_shift = np.empty([n_shift, 128, 1099])

# Process noise files
for i in range(n_noise):
    spec, mfccs, mel = feature2d(file_noise[i])
    if spec is not None:  # Ensure the file was processed correctly
        spec_noise[i], mfccs_noise[i], mel_noise[i] = spec, mfccs, mel

# Process shift files
for i in range(n_shift):
    spec, mfccs, mel = feature2d(file_shift[i])
    if spec is not None:  # Ensure the file was processed correctly
        spec_shift[i], mfccs_shift[i], mel_shift[i] = spec, mfccs, mel

# %%
def getMood(mood_list, file_list):
    for i in range(len(file_list)):
        m = os.path.basename(os.path.dirname(file_list[i]))
        mood_list.append(m)
    return mood_list

# %%
mood_noise_2d = []
mood_noise_2d = getMood(mood_noise_2d,file_noise)

# %%
mood_shift_2d = []
mood_shift_2d = getMood(mood_shift_2d,file_shift)

# %%
le = LabelEncoder()
moodtrans_noise =le.fit(np.array(mood_noise_2d))
moodtrans_noise=le.transform(np.array(mood_noise_2d))   

moodtrans_shift =le.fit(np.array(mood_shift_2d))
moodtrans_shift=le.transform(np.array(mood_shift_2d))

# %%
np.savez_compressed("D:/UM/Project/Mozartify/project/Datasets/Features/Features2D/Features_noise.npz", 
                    spec = spec_noise, 
                    mfcc = mfccs_noise,
                    mel = mel_noise,
                    target = moodtrans_noise)

# %%
np.savez_compressed("D:/UM/Project/Mozartify/project/Datasets/Features/Features2D/Features_shift.npz", 
                    spec = spec_shift, 
                    mfcc = mfccs_shift,
                    mel = mel_shift,
                    target = moodtrans_shift)
