# %% [markdown]
# ## 1. Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
'''--------- 1. Data Manipulation ---------'''
import numpy as np
import pandas as pd
'''--------- 2. Data Preprocessing ---------'''
from sklearn.preprocessing import LabelEncoder #Encode Non-numeric Var
from sklearn.preprocessing import MinMaxScaler # Feature Scaling
from sklearn.model_selection import train_test_split #Train Test Validation Split
'''--------- 3. Data Visualization ---------'''
import seaborn as sns
import matplotlib.pyplot as plt
'''--------- 4. Model Training ---------'''
import tensorflow as tf
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
'''--------- 5. Model Evluation ---------'''
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
'''--------- 6. Others ---------'''
import random
from pydub import AudioSegment
from IPython import display
import librosa

# %% [markdown]
# ## 2. Load Excel File

# %%
df = pd.read_excel("D:/UM/Project/Mozartify/project/Datasets/Features/Features1D/Features1D.xlsx")
df
# Out:
#      Unnamed: 0                                               file  scale key  \
# 0             0  D:/UM/Project/Mozartify/project/Datasets/audio...  major   D
# 1             1  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# 2             2  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 3             3  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 4             4  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# ..          ...                                                ...    ...  ..
# 968         968  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 969         969  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  G#
# 970         970  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# 971         971  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 972         972  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  F#
#
#           tempo  rms_mean   rms_var  chroma_mean  chroma_var  centroid_mean  \
# 0    135.999178  0.171184  0.003348     0.344088    0.098565    2289.203183
# 1    107.666016  0.106427  0.000725     0.416452    0.090011    2129.307062
# 2     99.384014  0.241972  0.010910     0.435837    0.084253    2980.267152
# 3    107.666016  0.120562  0.002160     0.420664    0.079768    2882.799693
# 4    129.199219  0.192818  0.003956     0.274221    0.085475    2146.962603
# ..          ...       ...       ...          ...         ...            ...
# 968  151.999081  0.097105  0.000582     0.293956    0.088207    1997.276683
# 969   89.102909  0.083837  0.001618     0.272151    0.084929    1331.011559
# 970   99.384014  0.076661  0.000290     0.237400    0.089330    1681.161502
# 971   99.384014  0.071242  0.001089     0.263051    0.092084    2075.571372
# 972   99.384014  0.054451  0.000717     0.226404    0.087524    1857.736709
#
#      ...  mfcc_var_16  mfcc_mean_17  mfcc_var_17  mfcc_mean_18  mfcc_var_18  \
# 0    ...    97.696182     -3.537810    71.402687     -0.436729    66.260963
# 1    ...    37.896637     -9.209418    46.455044     -1.426528    50.276150
# 2    ...    67.306412     -6.006174    66.395699     -1.117358    49.001869
# 3    ...    33.676331     -4.147554    37.201412     -3.797808    32.774509
# 4    ...    28.778049    -10.854812    36.313950     -0.480542    47.509182
# ..   ...          ...           ...          ...           ...          ...
# 968  ...    52.399574    -18.951229    71.105469     -6.146902    61.915462
# 969  ...    37.900272    -11.959914    43.625828     -5.335443    40.348934
# 970  ...    46.293671     -5.706831    39.779736     -3.286500    47.729607
# 971  ...    45.630798    -16.532892    45.669132    -11.235711    48.995541
# 972  ...    46.131042     -5.977736    78.518745      2.433602    74.181198
#
#      mfcc_mean_19  mfcc_var_19  mfcc_mean_20  mfcc_var_20   mood
# 0       -0.202857    59.259083      0.894741    47.133595  happy
# 1       -3.567492    65.857529      1.226228    85.487991  happy
# 2       -4.630496    50.317497      0.654567    79.517960  happy
# 3       -8.426100    32.341358     -6.023935    30.663700  happy
# 4       -4.177841    60.641903      6.327812    64.390320  happy
# ..            ...          ...           ...          ...    ...
# 968    -16.994026    55.398777    -14.183487    64.577774    sad
# 969    -10.943409    37.393105    -15.349643    56.387405    sad
# 970      1.990399    70.187508      5.452133    70.151512    sad
# 971    -15.730806    54.862488    -15.158969    68.118660    sad
# 972     -2.228051    73.092354     -5.549421    73.862915    sad
#
# [973 rows x 60 columns]

# %%
df_noise = pd.read_excel("D:/UM/Project/Mozartify/project/Datasets/Features/Features1D/Features_noise.xlsx")
df_noise
# Out:
#      Unnamed: 0                                               file  scale key  \
# 0             0  D:/UM/Project/Mozartify/project/Datasets/audio...  major   D
# 1             1  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# 2             2  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 3             3  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 4             4  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# ..          ...                                                ...    ...  ..
# 968         968  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 969         969  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  G#
# 970         970  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# 971         971  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 972         972  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  F#
#
#           tempo  rms_mean   rms_var  chroma_mean  chroma_var  centroid_mean  \
# 0    135.999178  0.172551  0.003279     0.346737    0.097540    2966.634004
# 1    107.666016  0.108430  0.000697     0.425311    0.088677    3245.481036
# 2     99.384014  0.242929  0.010846     0.438916    0.083680    3349.734719
# 3    107.666016  0.122461  0.002094     0.429079    0.077916    3441.083045
# 4    129.199219  0.194006  0.003910     0.276141    0.085043    2714.529319
# ..          ...       ...       ...          ...         ...            ...
# 968  151.999081  0.099292  0.000553     0.302301    0.086560    3586.618854
# 969   89.102909  0.086727  0.001535     0.288060    0.082760    3649.597341
# 970   99.384014  0.079354  0.000271     0.249582    0.087047    3687.129803
# 971   99.384014  0.074790  0.000973     0.291124    0.089676    3945.450852
# 972  103.359375  0.058689  0.000631     0.256780    0.083459    4186.240709
#
#      ...  mfcc_var_16  mfcc_mean_17  mfcc_var_17  mfcc_mean_18  mfcc_var_18  \
# 0    ...    85.576714     -1.930645    56.159031     -0.892971    51.551453
# 1    ...    27.379467     -5.753342    32.791855     -4.232408    35.934994
# 2    ...    59.253696     -4.593424    57.105923     -2.326811    42.335182
# 3    ...    29.263926     -2.092536    28.378841     -3.750346    26.634878
# 4    ...    22.606628     -7.715428    26.561018     -3.081796    38.821686
# ..   ...          ...           ...          ...           ...          ...
# 968  ...    25.648636    -11.969786    31.615791     -8.434127    28.832972
# 969  ...    24.422441    -10.237507    20.169052     -8.180056    21.755917
# 970  ...    22.693632     -1.819579    22.148537     -2.206744    27.014732
# 971  ...    26.464180     -9.677834    28.049032     -9.241619    24.549885
# 972  ...    26.027870     -4.082352    37.917431     -1.456431    32.269768
#
#      mfcc_mean_19  mfcc_var_19  mfcc_mean_20  mfcc_var_20   mood
# 0        0.633405    47.186474      0.253610    38.859661  happy
# 1       -1.325320    49.086235     -1.749682    67.460434  happy
# 2       -3.384727    42.804070     -0.737544    61.920296  happy
# 3       -5.963063    27.701960     -6.120047    26.094809  happy
# 4       -1.843145    54.758949      4.226146    58.505424  happy
# ..            ...          ...           ...          ...    ...
# 968    -11.089932    23.921122    -12.584082    28.737524    sad
# 969     -9.295341    18.762970    -10.592243    30.263374    sad
# 970      1.092161    37.564590      2.067389    34.046097    sad
# 971     -9.959146    28.012188    -10.346671    40.555420    sad
# 972     -2.180017    30.874439     -4.235230    33.675522    sad
#
# [973 rows x 60 columns]

# %%
df_shift = pd.read_excel("D:/UM/Project/Mozartify/project/Datasets/Features/Features1D/Features_shift.xlsx")
df_shift
# Out:
#      Unnamed: 0                                               file  scale key  \
# 0             0  D:/UM/Project/Mozartify/project/Datasets/audio...  major   D
# 1             1  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# 2             2  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 3             3  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 4             4  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# ..          ...                                                ...    ...  ..
# 968         968  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 969         969  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  G#
# 970         970  D:/UM/Project/Mozartify/project/Datasets/audio...  major   E
# 971         971  D:/UM/Project/Mozartify/project/Datasets/audio...  major   A
# 972         972  D:/UM/Project/Mozartify/project/Datasets/audio...  minor  F#
#
#           tempo  rms_mean   rms_var  chroma_mean  chroma_var  centroid_mean  \
# 0    135.999178  0.171162  0.003351     0.340845    0.097614    2289.203108
# 1    107.666016  0.106434  0.000724     0.414449    0.089709    2128.873013
# 2     99.384014  0.241991  0.010835     0.435087    0.083844    2979.436280
# 3    112.347147  0.120569  0.002160     0.421653    0.079912    2884.974018
# 4    129.199219  0.192869  0.003973     0.272747    0.084913    2147.226175
# ..          ...       ...       ...          ...         ...            ...
# 968  151.999081  0.097108  0.000583     0.294316    0.088250    1996.638353
# 969   89.102909  0.083857  0.001617     0.272484    0.085090    1331.675571
# 970   99.384014  0.076663  0.000291     0.237296    0.089185    1681.076015
# 971   99.384014  0.071239  0.001091     0.263241    0.092150    2075.791687
# 972   95.703125  0.054446  0.000716     0.226684    0.087591    1858.374251
#
#      ...  mfcc_var_16  mfcc_mean_17  mfcc_var_17  mfcc_mean_18  mfcc_var_18  \
# 0    ...    97.515526     -3.539253    71.415993     -0.424872    66.437180
# 1    ...    37.903477     -9.216166    46.307808     -1.430186    50.143211
# 2    ...    67.475204     -6.002207    66.501785     -1.109421    48.929623
# 3    ...    33.690018     -4.149460    37.224216     -3.795806    32.814350
# 4    ...    28.748222    -10.841578    36.262440     -0.469117    47.630962
# ..   ...          ...           ...          ...           ...          ...
# 968  ...    52.284241    -18.933998    71.058098     -6.168517    61.867592
# 969  ...    37.903763    -11.966993    43.538395     -5.346477    40.368793
# 970  ...    46.474285     -5.677488    40.483074     -3.268615    47.944653
# 971  ...    45.625221    -16.519905    45.574238    -11.216208    48.625031
# 972  ...    46.052235     -5.974515    78.356987      2.442869    74.308540
#
#      mfcc_mean_19  mfcc_var_19  mfcc_mean_20  mfcc_var_20   mood
# 0       -0.199554    59.399525      0.886875    47.189739  happy
# 1       -3.562091    65.681473      1.210580    85.589287  happy
# 2       -4.635880    50.368835      0.668790    79.389671  happy
# 3       -8.422532    32.291790     -6.022736    30.629898  happy
# 4       -4.169499    60.776985      6.336962    64.402382  happy
# ..            ...          ...           ...          ...    ...
# 968    -16.978498    55.321728    -14.182650    64.533455    sad
# 969    -10.921440    37.538857    -15.324995    56.659206    sad
# 970      1.989569    70.061569      5.450746    69.814407    sad
# 971    -15.720529    54.754559    -15.151942    68.066071    sad
# 972     -2.236240    73.018707     -5.541601    73.778122    sad
#
# [973 rows x 60 columns]

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### 3.1 Split Features and Labels

# %%
X = df.drop(['mood'],axis=1)
y = df['mood']

X_noise = df_noise.drop(['mood'],axis=1)
y_noise = df_noise['mood']

X_shift = df_shift.drop(['mood'],axis=1)
y_shift = df_shift['mood']

# %% [markdown]
# ### 2.2 Encode the non-numerical features labels
#
# **Encode the labels in numerical way:**
# - Happy: 1
# - Angry: 0
# - Relaxed: 2
# - Sad: 3

# %%
le = LabelEncoder()

le.fit(y)
y = le.transform(y)

le.fit(y_noise)
y_noise = le.transform(y_noise)

le.fit(y_shift)
y_shift = le.transform(y_shift)

# %% [markdown]
# **Encode the non-numeric variable scale:**
# - major: 0
# - minor: 1

# %%
le.fit(X['scale'])
X['scale'] = le.transform(X['scale'])

le.fit(X_noise['scale'])
X_noise['scale'] = le.transform(X_noise['scale'])

le.fit(X_shift['scale'])
X_shift['scale'] = le.transform(X_shift['scale'])

# %% [markdown]
# **Encode the non-numeric variable key:**
# - A: 0
# - A#: 1
# - B: 2
# - C: 3
# - C#: 4
# - D: 5
# - D#: 6
# - E: 7
# - F: 8
# - F#: 9
# - G: 10
# - G#: 11

# %%
le.fit(X['key'])
X['key'] = le.transform(X['key'])

le.fit(X_noise['key'])
X_noise['key'] = le.transform(X_noise['key'])

le.fit(X_shift['key'])
X_shift['key'] = le.transform(X_shift['key'])

# %% [markdown]
# ### 2.3 Train Test Validation Split
# Finally, split the dataset into train and test set, 80% of data are used as train set, 10% of data are used as test set and the remaining ones are used for validation set.

# %%
X0_train, X_test, y0_train, y_test = train_test_split(X, y, 
                                                      train_size = 0.7, 
                                                      random_state = 13,  
                                                      stratify = y)

# %%
X_train = pd.concat([X0_train,X_noise,X_shift])
y_train = np.concatenate((y0_train,y_noise,y_shift),axis=0)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  train_size = 0.8, 
                                                  random_state = 13, 
                                                  shuffle = True, 
                                                  stratify = y_train)

# %%
# Drop the 'file' column since it's not numeric and not needed for scaling
X_train = X_train.drop(columns=['file'])
X_val = X_val.drop(columns=['file'])
X_test = X_test.drop(columns=['file'])

# %% [markdown]
# ### 2.4 Feature Scaling
# As the range of the variales varies distinctly, in order to make the learning process better, the features need to be scaled into similar ranges. Here the Min-Max Scaler is used.

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train.iloc[:,1:])
X_val_scaled = scaler.fit_transform(X_val.iloc[:,1:])
X_test_scaled = scaler.fit_transform(X_test.iloc[:,1:])

# %%
# Define Model Builder of 3 conv1D layers and 2 fully connected layers
# Input data and paras of layers are changable

def modelBuilder3L(X_train,
                 f1,k1,a1,
                 f2,k2,a2,
                 f3,k3,a3,
                 d1,dr1,da1,r1,
                 d2,dr2,da2,r2,
                 num):
    '''
    args:
    
    X_train: training data
    f1,k1,a1: num of filters, filter size and activation func of 1st conv1D layer
    f2,k2,a2: num of filters, filter size and activation func of 2nd conv1D layer
    f3,k3,a3: num of filters, filter size and activation func of 3rd conv1D layer
    d1,dr1,da1, r1: num of units, dropout, activation func and regularizer para of 1st fully connected layer
    d2,dr2,da2, r2: num of units, dropout, activation func and regularizer para of 2nd fully connected layer
    num: integer for distinguishing different model
    
    return:
    model
    
    '''
    model = Sequential(name="Conv1D_"+str(num))

    m,n = X_train.shape

    #layer 1
    model.add(Conv1D(filters = f1, kernel_size = k1, input_shape = (n,1), padding = 'same', activation = a1, name ='Conv1D_1'))
    model.add(BatchNormalization(name = "BN1"))
    model.add(MaxPooling1D(name = "MaxPooling1"))
    #layer 2
    model.add(Conv1D(filters = f2, kernel_size = k2, activation = a2, padding='same', name = "Conv1D_2"))
    model.add(BatchNormalization(name = "BN2"))
    model.add(MaxPooling1D(name = "MaxPooling2"))
    #layer 3
    model.add(Conv1D(filters = f3, kernel_size = k3, activation = a3, padding='same', name = "Conv1D_3"))
    model.add(BatchNormalization(name = "BN3"))
    model.add(MaxPooling1D(name = "MaxPooling3"))
    #Flatten output
    model.add(Flatten(name = "Flatten"))

    #Fully connected layer 4
    model.add(Dense(d1, activation = da1, name = "Dense_1"))
    #Prevent overfitting
    model.add(Dropout(dr1, name = "Dropout_1"))

    #Fully connected layer 6
    model.add(Dense(d2, activation = da2, name = "Dense_2"))
    #Prevent overfitting
    model.add(Dropout(dr2, name = "Dropout_2"))

    #Output layer
    model.add(Dense(4, activation = 'softmax', name = "Softmax"))

    #model compiling
    optimizer = Adam(learning_rate=0.0001)
    model.compile(loss = 'sparse_categorical_crossentropy', optimizer = optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
f1,k1,a1 = 16,5,'relu'
f2,k2,a2 = 32,7,'relu'
f3,k3,a3 = 32,7,'relu'
d1,dr1,da1,r1 = 128,0.2,'relu',0.15
d2,dr2,da2,r2 = 64,0.2,'relu',0.15
num = 1

model = modelBuilder3L(X_train_scaled,
                        f1,k1,a1,
                        f2,k2,a2,
                        f3,k3,a3,
                        d1,dr1,da1,r1,
                        d2,dr2,da2,r2,
                        num)
# Out:
# Model: "Conv1D_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Conv1D_1 (Conv1D)               │ (None, 57, 16)         │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN1 (BatchNormalization)        │ (None, 57, 16)         │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPooling1 (MaxPooling1D)      │ (None, 28, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv1D_2 (Conv1D)               │ (None, 28, 32)         │         3,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN2 (BatchNormalization)        │ (None, 28, 32)         │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPooling2 (MaxPooling1D)      │ (None, 14, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv1D_3 (Conv1D)               │ (None, 14, 32)         │         7,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN3 (BatchNormalization)        │ (None, 14, 32)         │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPooling3 (MaxPooling1D)      │ (None, 7, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_1 (Dense)                 │ (None, 128)            │        28,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Softmax (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 48,548 (189.64 KB)
#  Trainable params: 48,388 (189.02 KB)
#  Non-trainable params: 160 (640.00 B)

# %%
history = model.fit(X_train_scaled, y_train, 
                    validation_data=(X_val_scaled, y_val), 
                    batch_size=16, epochs=80)
# Out:
# Epoch 1/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3506 - loss: 1.6509 - val_accuracy: 0.3384 - val_loss: 1.3476
# Epoch 2/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5122 - loss: 1.0833 - val_accuracy: 0.3441 - val_loss: 1.2868
# Epoch 3/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5641 - loss: 0.9570 - val_accuracy: 0.4030 - val_loss: 1.1615
# Epoch 4/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5910 - loss: 0.9003 - val_accuracy: 0.5266 - val_loss: 1.0093
# Epoch 5/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6375 - loss: 0.8260 - val_accuracy: 0.5760 - val_loss: 0.8926
# Epoch 6/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6468 - loss: 0.7862 - val_accuracy: 0.5894 - val_loss: 0.8768
# Epoch 7/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6549 - loss: 0.7796 - val_accuracy: 0.5951 - val_loss: 0.8697
# Epoch 8/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6746 - loss: 0.7471 - val_accuracy: 0.6103 - val_loss: 0.8564
# Epoch 9/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7257 - loss: 0.6576 - val_accuracy: 0.6008 - val_loss: 0.8616
# Epoch 10/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7031 - loss: 0.6825 - val_accuracy: 0.6236 - val_loss: 0.8510
# Epoch 11/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7480 - loss: 0.6397 - val_accuracy: 0.6236 - val_loss: 0.8492
# Epoch 12/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7416 - loss: 0.6059 - val_accuracy: 0.6179 - val_loss: 0.8432
# Epoch 13/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7554 - loss: 0.5782 - val_accuracy: 0.6255 - val_loss: 0.8411
# Epoch 14/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7450 - loss: 0.5791 - val_accuracy: 0.6141 - val_loss: 0.8485
# Epoch 15/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7814 - loss: 0.5385 - val_accuracy: 0.6198 - val_loss: 0.8593
# Epoch 16/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7633 - loss: 0.5262 - val_accuracy: 0.5970 - val_loss: 0.8694
# Epoch 17/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8158 - loss: 0.4762 - val_accuracy: 0.6293 - val_loss: 0.8484
# Epoch 18/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8088 - loss: 0.4586 - val_accuracy: 0.5970 - val_loss: 0.9011
# Epoch 19/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8259 - loss: 0.4403 - val_accuracy: 0.5970 - val_loss: 0.8810
# Epoch 20/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8325 - loss: 0.4341 - val_accuracy: 0.5932 - val_loss: 0.8614
# Epoch 21/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8309 - loss: 0.4268 - val_accuracy: 0.6141 - val_loss: 0.8671
# Epoch 22/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8461 - loss: 0.3996 - val_accuracy: 0.6008 - val_loss: 0.8936
# Epoch 23/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8484 - loss: 0.3818 - val_accuracy: 0.6103 - val_loss: 0.9199
# Epoch 24/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8632 - loss: 0.3602 - val_accuracy: 0.5951 - val_loss: 0.8980
# Epoch 25/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8667 - loss: 0.3513 - val_accuracy: 0.6255 - val_loss: 0.8949
# Epoch 26/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8725 - loss: 0.3502 - val_accuracy: 0.6217 - val_loss: 0.8961
# Epoch 27/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8918 - loss: 0.3034 - val_accuracy: 0.6236 - val_loss: 0.8909
# Epoch 28/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8827 - loss: 0.2972 - val_accuracy: 0.5970 - val_loss: 0.9640
# Epoch 29/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8921 - loss: 0.2912 - val_accuracy: 0.6407 - val_loss: 0.8943
# Epoch 30/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8884 - loss: 0.2948 - val_accuracy: 0.6350 - val_loss: 0.9160
# Epoch 31/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9095 - loss: 0.2499 - val_accuracy: 0.6217 - val_loss: 0.9021
# Epoch 32/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9209 - loss: 0.2392 - val_accuracy: 0.6160 - val_loss: 1.0379
# Epoch 33/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9154 - loss: 0.2415 - val_accuracy: 0.5970 - val_loss: 1.0577
# Epoch 34/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9156 - loss: 0.2285 - val_accuracy: 0.6217 - val_loss: 1.0149
# Epoch 35/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9205 - loss: 0.2149 - val_accuracy: 0.6160 - val_loss: 1.0432
# Epoch 36/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9250 - loss: 0.2119 - val_accuracy: 0.6236 - val_loss: 1.0118
# Epoch 37/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9261 - loss: 0.1987 - val_accuracy: 0.6103 - val_loss: 1.0689
# Epoch 38/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9375 - loss: 0.1920 - val_accuracy: 0.6046 - val_loss: 1.1204
# Epoch 39/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9352 - loss: 0.1920 - val_accuracy: 0.6407 - val_loss: 1.0505
# Epoch 40/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9448 - loss: 0.1655 - val_accuracy: 0.6236 - val_loss: 1.0717
# Epoch 41/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9439 - loss: 0.1578 - val_accuracy: 0.5989 - val_loss: 1.1558
# Epoch 42/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9620 - loss: 0.1374 - val_accuracy: 0.6065 - val_loss: 1.1573
# Epoch 43/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9523 - loss: 0.1479 - val_accuracy: 0.6255 - val_loss: 1.1224
# Epoch 44/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9484 - loss: 0.1396 - val_accuracy: 0.6236 - val_loss: 1.1558
# Epoch 45/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9653 - loss: 0.1307 - val_accuracy: 0.6198 - val_loss: 1.2446
# Epoch 46/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9575 - loss: 0.1198 - val_accuracy: 0.6065 - val_loss: 1.3013
# Epoch 47/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9482 - loss: 0.1332 - val_accuracy: 0.6540 - val_loss: 1.1292
# Epoch 48/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9579 - loss: 0.1328 - val_accuracy: 0.6483 - val_loss: 1.1451
# Epoch 49/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9597 - loss: 0.1096 - val_accuracy: 0.6179 - val_loss: 1.2782
# Epoch 50/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9558 - loss: 0.1227 - val_accuracy: 0.6483 - val_loss: 1.1649
# Epoch 51/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9700 - loss: 0.0941 - val_accuracy: 0.6160 - val_loss: 1.2809
# Epoch 52/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.0980 - val_accuracy: 0.6350 - val_loss: 1.2152
# Epoch 53/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9728 - loss: 0.0933 - val_accuracy: 0.6179 - val_loss: 1.3631
# Epoch 54/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9752 - loss: 0.0827 - val_accuracy: 0.6255 - val_loss: 1.3398
# Epoch 55/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.0937 - val_accuracy: 0.6331 - val_loss: 1.3497
# Epoch 56/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9728 - loss: 0.0873 - val_accuracy: 0.6388 - val_loss: 1.2800
# Epoch 57/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9676 - loss: 0.0918 - val_accuracy: 0.6274 - val_loss: 1.3826
# Epoch 58/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9781 - loss: 0.0756 - val_accuracy: 0.6255 - val_loss: 1.4183
# Epoch 59/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9750 - loss: 0.0785 - val_accuracy: 0.6388 - val_loss: 1.5007
# Epoch 60/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9751 - loss: 0.0810 - val_accuracy: 0.6274 - val_loss: 1.4554
# Epoch 61/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9797 - loss: 0.0679 - val_accuracy: 0.6388 - val_loss: 1.3985
# Epoch 62/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9729 - loss: 0.0827 - val_accuracy: 0.6445 - val_loss: 1.3941
# Epoch 63/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9811 - loss: 0.0605 - val_accuracy: 0.6426 - val_loss: 1.4451
# Epoch 64/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9834 - loss: 0.0607 - val_accuracy: 0.6122 - val_loss: 1.6537
# Epoch 65/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9813 - loss: 0.0578 - val_accuracy: 0.6521 - val_loss: 1.4386
# Epoch 66/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.0579 - val_accuracy: 0.6407 - val_loss: 1.5719
# Epoch 67/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9788 - loss: 0.0577 - val_accuracy: 0.6350 - val_loss: 1.5707
# Epoch 68/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9853 - loss: 0.0464 - val_accuracy: 0.6103 - val_loss: 1.6938
# Epoch 69/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9855 - loss: 0.0425 - val_accuracy: 0.6616 - val_loss: 1.5741
# Epoch 70/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0394 - val_accuracy: 0.6635 - val_loss: 1.5023
# Epoch 71/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.0447 - val_accuracy: 0.6464 - val_loss: 1.5868
# Epoch 72/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9847 - loss: 0.0458 - val_accuracy: 0.6350 - val_loss: 1.6244
# Epoch 73/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9877 - loss: 0.0422 - val_accuracy: 0.6483 - val_loss: 1.6469
# Epoch 74/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9823 - loss: 0.0460 - val_accuracy: 0.6407 - val_loss: 1.7839
# Epoch 75/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9857 - loss: 0.0484 - val_accuracy: 0.6369 - val_loss: 1.7486
# Epoch 76/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9862 - loss: 0.0459 - val_accuracy: 0.6464 - val_loss: 1.6982
# Epoch 77/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9884 - loss: 0.0353 - val_accuracy: 0.6464 - val_loss: 1.6690
# Epoch 78/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9897 - loss: 0.0326 - val_accuracy: 0.6407 - val_loss: 1.8263
# Epoch 79/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - loss: 0.0261 - val_accuracy: 0.6160 - val_loss: 1.8972
# Epoch 80/80
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9805 - loss: 0.0500 - val_accuracy: 0.6407 - val_loss: 1.7096

# %%
model.save('D:/UM/Project/Mozartify/project/Model/CNN_models/1D_CNN/Conv1D_Augmented.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Train and Validation accuracy and loss
f = plt.figure(figsize = (12,4))

plt.subplot(1,2,1)
plt.title('train validation accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['train','validation'])
plt.xlabel('epoch')
plt.ylabel('accuracy')


plt.subplot(1,2,2)
plt.title('train validation loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
y_prob = model.predict(X_test_scaled)
y_pred = np.argmax(y_prob, axis = -1)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# Accuracy
acc_1d = round(accuracy_score(y_pred,y_test),2)

# %%
acc_1d
# Out:
# 0.73

# %%
# Confusion Matrix
cm_1d = confusion_matrix(y_test,y_pred)
cm_display_1d = ConfusionMatrixDisplay(confusion_matrix = cm_1d, display_labels = ['Happy', 'Relaxed', 'Sad'])

# %%
print(classification_report(y_test, y_pred, target_names = ['Happy', 'Relaxed', 'Sad']))
cm_display_1d.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Happy       0.77      0.79      0.78        97
#      Relaxed       0.75      0.67      0.71        98
#          Sad       0.66      0.71      0.69        97
#
#     accuracy                           0.73       292
#    macro avg       0.73      0.73      0.73       292
# weighted avg       0.73      0.73      0.73       292
